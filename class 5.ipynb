# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Downloads/CarPrice_Assignment.csv')

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.head().transpose()
# Out:
#                                    0                    1  \
# car_ID                             1                    2
# symboling                          3                    3
# CarName           alfa-romero giulia  alfa-romero stelvio
# fueltype                         gas                  gas
# aspiration                       std                  std
# doornumber                       two                  two
# carbody                  convertible          convertible
# drivewheel                       rwd                  rwd
# enginelocation                 front                front
# wheelbase                       88.6                 88.6
# carlength                      168.8                168.8
# carwidth                        64.1                 64.1
# carheight                       48.8                 48.8
# curbweight                      2548                 2548
# enginetype                      dohc                 dohc
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data['CarName'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
data['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
data['doornumber']
# Out:
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
#        ...
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: doornumber, Length: 205, dtype: object

# %%
data.sample(10)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 118     119          1         plymouth fury iii      gas        std
# 155     156          0             toyota carina      gas        std
# 53       54          1                mazda rx-4      gas        std
# 46       47          2              isuzu D-Max       gas        std
# 127     128          3           porsche cayenne      gas        std
# 67       68         -1  buick electra 225 custom   diesel      turbo
# 134     135          3                 saab 99le      gas        std
# 56       57          3                 mazda glc      gas        std
# 6         7          1                audi 100ls      gas        std
# 17       18          0                    bmw x3      gas        std
#
#     doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 118        two  hatchback        fwd          front       93.7  ...
# 155       four      wagon        4wd          front       95.7  ...
# ...

# %%
data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data['wheelbase'].median()
# Out:
# 97.0

# %%
data['wheelbase'].fillna(np.mean)
# Out:
# 0       88.6
# 1       88.6
# 2       94.5
# 3       99.8
# 4       99.4
#        ...
# 200    109.1
# 201    109.1
# 202    109.1
# 203    109.1
# 204    109.1
# Name: wheelbase, Length: 205, dtype: float64

# %%
data['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
data['carbody'].nunique()
# Out:
# 5

# %%
data.loc[0:150,:]
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 146     147          0             subaru trezia      gas        std
# 147     148          0            subaru tribeca      gas        std
# 148     149          0                 subaru dl      gas        std
# 149     150          0                 subaru dl      gas      turbo
# 150     151          1     toyota corona mark ii      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.iloc[4,6:]
# Out:
# carbody               sedan
# drivewheel              4wd
# enginelocation        front
# wheelbase              99.4
# carlength             176.6
# carwidth               66.4
# carheight              54.3
# curbweight             2824
# enginetype              ohc
# cylindernumber         five
# enginesize              136
# fuelsystem             mpfi
# boreratio              3.19
# stroke                  3.4
# compressionratio        8.0
# horsepower              115
# peakrpm                5500
# citympg                  18
# highwaympg               22
# price               17450.0
# Name: 4, dtype: object

# %%
data.groupby(['carbody','fueltype']).sum()['price']
# Out:
# carbody      fueltype
# convertible  gas          131343.000
# hardtop      diesel        28176.000
#              gas          149492.000
# hatchback    diesel         7788.000
#              gas          718577.667
# sedan        diesel       221616.000
#              gas         1155434.000
# wagon        diesel        59183.000
#              gas          250116.000
# Name: price, dtype: float64

# %%
data.dropna()
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.drop_duplicates()

# %%
2 3 4
2 2 4
2 3 4
2 3 4

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.insert(3,'brand',data['CarName'].values)

# %%
data.drop(['brandname','brand'],axis = 1,inplace = True)

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
pd.crosstab(data['fueltype'],data['carbody'])
# Out:
# carbody   convertible  hardtop  hatchback  sedan  wagon
# fueltype
# diesel              0        1          1     15      3
# gas                 6        7         69     81     22

# %%
data.iloc[:20,:].sort_values(['highwaympg','price'],ascending=False)
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 18      19          2          chevrolet impala      gas        std
# 19      20          1     chevrolet monte carlo      gas        std
# 3        4          2               audi 100 ls      gas        std
# 11      12          0                  bmw 320i      gas        std
# 10      11          2                  bmw 320i      gas        std
# 13      14          0                    bmw x3      gas        std
# 12      13          0                    bmw x1      gas        std
# 1        2          3       alfa-romero stelvio      gas        std
# 0        1          3        alfa-romero giulia      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 14      15          1                    bmw z4      gas        std
# 7        8          1                 audi 5000      gas        std
# 6        7          1                audi 100ls      gas        std
# ...

# %%
data.rename(columns = {'CarName':'brandname'},inplace  =True)

# %%
data
# Out:
#      car_ID  symboling                 brandname fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data['fueltype'] = data['fueltype'].replace({'gas':'Gas','diesel':'Diesel'})
# Out:
# 0         Gas
# 1         Gas
# 2         Gas
# 3         Gas
# 4         Gas
#         ...
# 200       Gas
# 201       Gas
# 202       Gas
# 203    Diesel
# 204       Gas
# Name: fueltype, Length: 205, dtype: object

# %%
data['brandname']
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: brandname, Length: 205, dtype: object
